# %%
# I used folders in order: 200_1, 200_2, 100, 200_3, 200_4

# %matplotlib inline
import import_ipynb
import os
import random
from os import listdir
from os.path import isdir
from numpy import savez_compressed
from matplotlib import pyplot
from PIL import Image
from numpy import asarray
from scipy.spatial.distance import cosine
from mtcnn.mtcnn import MTCNN
from numpy import load
from keras_vggface.vggface import VGGFace
from keras_vggface.utils import preprocess_input
from time import perf_counter
import sys
import numpy as np
import io
import json
import math
import matplotlib.image as mpimg
from matplotlib import rcParams
import matplotlib.pyplot as plt
import ast
import tensorflow as tf
from numpy import expand_dims
from keras.models import load_model
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import Normalizer
from sklearn.svm import SVC
from scipy.spatial import distance
import scipy

def get_embeddings(filenames):
    # extract faces
    faces = [extract_face(f) for f in filenames]
    # convert into an array of samples
    samples = asarray(faces, 'float32')
    # prepare the face for the model, e.g. center pixels
    samples = preprocess_input(samples, version=2)
    # create predication model - note that we have several 
    model = VGGFace(model='resnet50', include_top=False, input_shape=(224, 224, 3), pooling='avg')
    # perform prediction
    yhat = model.predict(samples)
    return yhat

def get_embeddings_l(filenames):
    # extract faces
    faces = [extract_face(f) for f in filenames]
    # convert into an array of samples
    samples = asarray(faces, 'float32')
    # prepare the face for the model, e.g. center pixels
    samples = preprocess_input(samples, version=2)
    
    # Load the TFLite model and allocate tensors. View details
    
    interpreter = tf.lite.Interpreter(model_path="model_resnet50.tflite")
    interpreter.allocate_tensors()

    # Get input and output tensors.
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    # Test the model on input data.
    # input_shape = input_details[0]['shape']
    
    # Use same image as Keras model
    input_data = np.array(samples, dtype=np.float32)
    interpreter.set_tensor(input_details[0]['index'], input_data)
    interpreter.get_tensor_details()

    interpreter.invoke()

    # The function `get_tensor()` returns a copy of the tensor data.
    # Use `tensor()` in order to get a pointer to the tensor.
    output_data = interpreter.get_tensor(output_details[0]['index'])
    
    return output_data
def extract_face(filename, required_size=(224, 224)):
	# load image from file
	pixels = pyplot.imread(filename)
	# create the detector, using default weights
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)

	print(len(results), 'faces have been found')
#--------------------------- detecting the number of faces ------------------------------------
	if len(results) == 0:
		raise Exception('No faces detected')
	elif len(results) > 1:
		raise Exception('Multiple faces detected')		
        
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
	return face_array

def is_match_mass(known_embedding, candidate_embedding, thresh=0.5):
    score = cosine(known_embedding, candidate_embedding)
    return math.floor((1-score)*100)


baseDir = '/Users/denis/Downloads/lfw-deepfunneled200_1' 
outputDir = '/Users/denis/Desktop'
results = 'Person 1, Person 2, Expected, Result, Percent identity \n'

list = []

for entry in os.scandir(baseDir):
    
#     print("entry ----->",entry.path) 
    list.append(entry.path)

index = 0
targetFile = ''

for folder in list:
    targetFileName = os.listdir(folder)[0]
    targetFilePath = folder + '/' + targetFileName
    
    try:
        targetVector = get_embeddings_l([targetFilePath])
        
        count = 0
        while count < 5 :
            testFolder = random.choice(list)
            if testFolder != folder:
                testFileName = os.listdir(testFolder)[0]
                testFilePath = testFolder + '/' + testFileName
                try:
                    testVector = get_embeddings_l([testFilePath])
                    result = is_match_mass(targetVector, testVector)
                    textResult = 'Match'
                    print("\n--------------------->", result, index)
                    if result <= 50 :
                        textResult = 'Not Match'
                    print("results---------", results)

                    results = results + targetFileName + ',' + testFileName + ',' + 'Not match' +  ',' + textResult + ',' + str(result) + '\n'

                    count+=1

                except Exception as err:
                    print("---------multiple faces detected...-----------")
                    
    except Exception as err:
        print("---------multiple faces detected-----------")
    
    if index > 50:
        break
    index += 1
    
print(results)
output = open(outputDir + '/results200_test.csv', 'w')
output.write(results)
output.close()
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b019d90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1 faces have been found
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a908598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a908598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a908598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a908620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b286b70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1 faces have been found
#
# ---------------------> 25 0
# results--------- Person 1, Person 2, Expected, Result, Percent identity
#
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x1125c71e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x1125c71e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x1125c71e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14bf83bf8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a89d268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1 faces have been found
#
# ---------------------> 19 0
# results--------- Person 1, Person 2, Expected, Result, Percent identity
# Deb_Santos_0001.jpg,Daryl_Jones_0001.jpg,Not match,Not Match,25
#
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b1ae488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b1ae488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b1ae488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14c2a3ae8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14be1ce18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1 faces have been found
#
# ---------------------> 42 0
# results--------- Person 1, Person 2, Expected, Result, Percent identity
# Deb_Santos_0001.jpg,Daryl_Jones_0001.jpg,Not match,Not Match,25
# Deb_Santos_0001.jpg,Daniel_Ortega_0001.jpg,Not match,Not Match,19
#
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b382d90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b382d90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b382d90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b382730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14bdc0510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1 faces have been found
#
# ---------------------> 30 0
# results--------- Person 1, Person 2, Expected, Result, Percent identity
# Deb_Santos_0001.jpg,Daryl_Jones_0001.jpg,Not match,Not Match,25
# Deb_Santos_0001.jpg,Daniel_Ortega_0001.jpg,Not match,Not Match,19
# Deb_Santos_0001.jpg,David_Donohue_0001.jpg,Not match,Not Match,42
#
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b50a6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b50a6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b50a6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14bf83158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a85bb70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1 faces have been found
#
# ---------------------> 28 0
# results--------- Person 1, Person 2, Expected, Result, Percent identity
# Deb_Santos_0001.jpg,Daryl_Jones_0001.jpg,Not match,Not Match,25
# Deb_Santos_0001.jpg,Daniel_Ortega_0001.jpg,Not match,Not Match,19
# Deb_Santos_0001.jpg,David_Donohue_0001.jpg,Not match,Not Match,42
# Deb_Santos_0001.jpg,David_Arquette_0001.jpg,Not match,Not Match,30
#
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14bf83ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14bf83ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14bf83ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14bf0a2f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a7f67b8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1 faces have been found
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a89d950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a89d950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a89d950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b884378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14c2fd488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1 faces have been found
#
# ---------------------> 27 1
# results--------- Person 1, Person 2, Expected, Result, Percent identity
# Deb_Santos_0001.jpg,Daryl_Jones_0001.jpg,Not match,Not Match,25
# Deb_Santos_0001.jpg,Daniel_Ortega_0001.jpg,Not match,Not Match,19
# Deb_Santos_0001.jpg,David_Donohue_0001.jpg,Not match,Not Match,42
# Deb_Santos_0001.jpg,David_Arquette_0001.jpg,Not match,Not Match,30
# Deb_Santos_0001.jpg,David_Sousa_0001.jpg,Not match,Not Match,28
#
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14bcab048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14bcab048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14bcab048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14dac2d08> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14bf44620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1 faces have been found
#
# ---------------------> 36 1
# results--------- Person 1, Person 2, Expected, Result, Percent identity
# Deb_Santos_0001.jpg,Daryl_Jones_0001.jpg,Not match,Not Match,25
# Deb_Santos_0001.jpg,Daniel_Ortega_0001.jpg,Not match,Not Match,19
# Deb_Santos_0001.jpg,David_Donohue_0001.jpg,Not match,Not Match,42
# Deb_Santos_0001.jpg,David_Arquette_0001.jpg,Not match,Not Match,30
# Deb_Santos_0001.jpg,David_Sousa_0001.jpg,Not match,Not Match,28
# David_Wells_0001.jpg,Danny_Morgan_0001.jpg,Not match,Not Match,27
#
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14c2fd620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14c2fd620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14c2fd620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14dc689d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14db5e488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1 faces have been found
#
# ---------------------> 33 1
# results--------- Person 1, Person 2, Expected, Result, Percent identity
# Deb_Santos_0001.jpg,Daryl_Jones_0001.jpg,Not match,Not Match,25
# Deb_Santos_0001.jpg,Daniel_Ortega_0001.jpg,Not match,Not Match,19
# Deb_Santos_0001.jpg,David_Donohue_0001.jpg,Not match,Not Match,42
# Deb_Santos_0001.jpg,David_Arquette_0001.jpg,Not match,Not Match,30
# Deb_Santos_0001.jpg,David_Sousa_0001.jpg,Not match,Not Match,28
# David_Wells_0001.jpg,Danny_Morgan_0001.jpg,Not match,Not Match,27
# David_Wells_0001.jpg,Derrick_Taylor_0001.jpg,Not match,Not Match,36
#
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b619378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b619378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b619378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14dac2268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14bf44730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1 faces have been found
#
# ---------------------> 33 1
# results--------- Person 1, Person 2, Expected, Result, Percent identity
# Deb_Santos_0001.jpg,Daryl_Jones_0001.jpg,Not match,Not Match,25
# Deb_Santos_0001.jpg,Daniel_Ortega_0001.jpg,Not match,Not Match,19
# Deb_Santos_0001.jpg,David_Donohue_0001.jpg,Not match,Not Match,42
# Deb_Santos_0001.jpg,David_Arquette_0001.jpg,Not match,Not Match,30
# Deb_Santos_0001.jpg,David_Sousa_0001.jpg,Not match,Not Match,28
# David_Wells_0001.jpg,Danny_Morgan_0001.jpg,Not match,Not Match,27
# David_Wells_0001.jpg,Derrick_Taylor_0001.jpg,Not match,Not Match,36
# David_Wells_0001.jpg,David_Wolf_0002.jpg,Not match,Not Match,33
#
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a908ae8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a908ae8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a908ae8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14c2a32f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1 faces have been found
#
# ---------------------> 27 1
# results--------- Person 1, Person 2, Expected, Result, Percent identity
# Deb_Santos_0001.jpg,Daryl_Jones_0001.jpg,Not match,Not Match,25
# Deb_Santos_0001.jpg,Daniel_Ortega_0001.jpg,Not match,Not Match,19
# Deb_Santos_0001.jpg,David_Donohue_0001.jpg,Not match,Not Match,42
# Deb_Santos_0001.jpg,David_Arquette_0001.jpg,Not match,Not Match,30
# Deb_Santos_0001.jpg,David_Sousa_0001.jpg,Not match,Not Match,28
# David_Wells_0001.jpg,Danny_Morgan_0001.jpg,Not match,Not Match,27
# David_Wells_0001.jpg,Derrick_Taylor_0001.jpg,Not match,Not Match,36
# David_Wells_0001.jpg,David_Wolf_0002.jpg,Not match,Not Match,33
# David_Wells_0001.jpg,Denis_Coderre_0001.jpg,Not match,Not Match,33
#
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a89d598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14a89d598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# 1 faces have been found
#
# ---------------------> 25 39
# results--------- Person 1, Person 2, Expected, Result, Percent identity
# Deb_Santos_0001.jpg,Daryl_Jones_0001.jpg,Not match,Not Match,25
# Deb_Santos_0001.jpg,Daniel_Ortega_0001.jpg,Not match,Not Match,19
# Deb_Santos_0001.jpg,David_Donohue_0001.jpg,Not match,Not Match,42
# Deb_Santos_0001.jpg,David_Arquette_0001.jpg,Not match,Not Match,30
# Deb_Santos_0001.jpg,David_Sousa_0001.jpg,Not match,Not Match,28
# David_Wells_0001.jpg,Danny_Morgan_0001.jpg,Not match,Not Match,27
# David_Wells_0001.jpg,Derrick_Taylor_0001.jpg,Not match,Not Match,36
# David_Wells_0001.jpg,David_Wolf_0002.jpg,Not match,Not Match,33
# David_Wells_0001.jpg,Denis_Coderre_0001.jpg,Not match,Not Match,33
# David_Wells_0001.jpg,Darvis_Patton_0001.jpg,Not match,Not Match,27
# David_Brown_0001.jpg,David_Anderson_0001.jpg,Not match,Not Match,26
# David_Brown_0001.jpg,David_Braley_0001.jpg,Not match,Not Match,32
# David_Brown_0001.jpg,Danielle_Spencer_0001.jpg,Not match,Not Match,31
# David_Brown_0001.jpg,Debbie_Allen_0001.jpg,Not match,Not Match,24
# David_Brown_0001.jpg,Daniel_Rouse_0001.jpg,Not match,Not Match,24
# David_Zeplowitz_0001.jpg,Dave_Lewis_0001.jpg,Not match,Not Match,35
# David_Zeplowitz_0001.jpg,Demetrius_Ferraciu_0002.jpg,Not match,Not Match,32
# David_Zeplowitz_0001.jpg,Darrell_Dickey_0001.jpg,Not match,Not Match,43
# David_Zeplowitz_0001.jpg,Denys_Arcand_0001.jpg,Not match,Not Match,29
# David_Zeplowitz_0001.jpg,Debbie_Allen_0001.jpg,Not match,Not Match,35
# Dave_Tucker_0001.jpg,Deniz_Baykal_0001.jpg,Not match,Not Match,29
# Dave_Tucker_0001.jpg,David_Kelly_0001.jpg,Not match,Not Match,25
# Dave_Tucker_0001.jpg,Daniela_Cicarelli_0001.jpg,Not match,Not Match,32
# Dave_Tucker_0001.jpg,Dennis_Oswald_0001.jpg,Not match,Not Match,37
# Dave_Tucker_0001.jpg,Deepa_Mehta_0001.jpg,Not match,Not Match,38
# Denys_Arcand_0001.jpg,Daniela_Cicarelli_0001.jpg,Not match,Not Match,31
# Denys_Arcand_0001.jpg,Derek_Parra_0001.jpg,Not match,Not Match,24
# Denys_Arcand_0001.jpg,Dennis_Miller_0001.jpg,Not match,Not Match,29
# Denys_Arcand_0001.jpg,David_Hanson_0001.jpg,Not match,Not Match,22
# Denys_Arcand_0001.jpg,David_McKiernan_0001.jpg,Not match,Not Match,38
# Darren_Clarke_0001.jpg,Danny_Elfman_0001.jpg,Not match,Not Match,26
# Darren_Clarke_0001.jpg,Daryl_Smith_0001.jpg,Not match,Not Match,34
# Darren_Clarke_0001.jpg,David_Trimble_0005.jpg,Not match,Not Match,25
# Darren_Clarke_0001.jpg,Dave_Odom_0001.jpg,Not match,Not Match,26
# Darren_Clarke_0001.jpg,Dario_Franchitti_0001.jpg,Not match,Not Match,22
# Danny_Glover_0001.jpg,David_Brown_0001.jpg,Not match,Not Match,36
# Danny_Glover_0001.jpg,David_Arquette_0001.jpg,Not match,Not Match,24
# Danny_Glover_0001.jpg,David_Anderson_0001.jpg,Not match,Not Match,28
# Danny_Glover_0001.jpg,Dennis_Kozlowski_0001.jpg,Not match,Not Match,23
# Danny_Glover_0001.jpg,Dennis_Johnson_0001.jpg,Not match,Not Match,25
# Daniel_Day-Lewis_0001.jpg,David_Hannay_0001.jpg,Not match,Not Match,37
# Daniel_Day-Lewis_0001.jpg,Desmon_Farmer_0001.jpg,Not match,Not Match,20
# Daniel_Day-Lewis_0001.jpg,Daniel_Comisso_Urdaneta_0001.jpg,Not match,Not Match,37
# Daniel_Day-Lewis_0001.jpg,Daniel_Kurtzer_0001.jpg,Not match,Not Match,28
# Daniel_Day-Lewis_0001.jpg,Daniele_Hypolito_0001.jpg,Not match,Not Match,31
# Derrick_Battie_0001.jpg,David_Spade_0002.jpg,Not match,Not Match,35
# Derrick_Battie_0001.jpg,Daniel_Zelman_0001.jpg,Not match,Not Match,22
# Derrick_Battie_0001.jpg,David_Heyman_0001.jpg,Not match,Not Match,26
# Derrick_Battie_0001.jpg,Darvis_Patton_0001.jpg,Not match,Not Match,36
# Derrick_Battie_0001.jpg,Danny_Green_0001.jpg,Not match,Not Match,29
# David_Hilt_0001.jpg,David_Heyman_0001.jpg,Not match,Not Match,33
# David_Hilt_0001.jpg,Darvis_Patton_0001.jpg,Not match,Not Match,21
# David_Hilt_0001.jpg,Debbie_Reynolds_0004.jpg,Not match,Not Match,25
# David_Hilt_0001.jpg,Daniel_Ortega_0001.jpg,Not match,Not Match,32
# David_Hilt_0001.jpg,Daniel_Scioli_0001.jpg,Not match,Not Match,26
# Darryl_Stingley_0001.jpg,David_Blaine_0001.jpg,Not match,Not Match,33
# Darryl_Stingley_0001.jpg,Derrick_Rodgers_0001.jpg,Not match,Not Match,28
# Darryl_Stingley_0001.jpg,Dave_Potter_0001.jpg,Not match,Not Match,21
# Darryl_Stingley_0001.jpg,Daniel_Coats_0001.jpg,Not match,Not Match,22
# Darryl_Stingley_0001.jpg,Darlene_Garrettson_0001.jpg,Not match,Not Match,22
# David_Myers_0002.jpg,Davis_Love_III_0001.jpg,Not match,Not Match,39
# David_Myers_0002.jpg,Deena_Burnett_0001.jpg,Not match,Not Match,24
# David_Myers_0002.jpg,Desiree_Lemosi_0001.jpg,Not match,Not Match,21
# David_Myers_0002.jpg,David_Hanson_0001.jpg,Not match,Not Match,31
# David_Myers_0002.jpg,David_Caraway_0001.jpg,Not match,Not Match,32
# David_Eldon_0001.jpg,David_Siegel_0001.jpg,Not match,Not Match,30
# David_Eldon_0001.jpg,Dennis_Miller_0001.jpg,Not match,Not Match,31
# David_Eldon_0001.jpg,David_Gest_0001.jpg,Not match,Not Match,30
# David_Eldon_0001.jpg,Daniel_Scioli_0001.jpg,Not match,Not Match,29
# David_Eldon_0001.jpg,Daniel_Comisso_Urdaneta_0001.jpg,Not match,Not Match,36
# Derek_Bond_0001.jpg,Dave_Ragone_0001.jpg,Not match,Not Match,23
# Derek_Bond_0001.jpg,David_Hasselhoff_0001.jpg,Not match,Not Match,22
# Derek_Bond_0001.jpg,David_Anderson_0001.jpg,Not match,Not Match,34
# Derek_Bond_0001.jpg,Dave_Williams_0001.jpg,Not match,Not Match,28
# Derek_Bond_0001.jpg,Daniel_Comisso_Urdaneta_0001.jpg,Not match,Not Match,27
# Desmon_Farmer_0001.jpg,David_Gest_0001.jpg,Not match,Not Match,14
# Desmon_Farmer_0001.jpg,Dave_Campo_0001.jpg,Not match,Not Match,28
# Desmon_Farmer_0001.jpg,Debbie_Allen_0001.jpg,Not match,Not Match,35
# Desmon_Farmer_0001.jpg,David_Modell_0001.jpg,Not match,Not Match,25
# Desmon_Farmer_0001.jpg,David_Beckham_0002.jpg,Not match,Not Match,25
# Dave_Matthews_0001.jpg,Derek_Lowe_0002.jpg,Not match,Not Match,35
# Dave_Matthews_0001.jpg,Danny_Elfman_0001.jpg,Not match,Not Match,32
# Dave_Matthews_0001.jpg,Daniel_Rouse_0001.jpg,Not match,Not Match,30
# Dave_Matthews_0001.jpg,Danny_Ainge_0001.jpg,Not match,Not Match,19
# Dave_Matthews_0001.jpg,David_Spade_0002.jpg,Not match,Not Match,26
# Danielle_Spencer_0001.jpg,Daniel_Barenboim_0001.jpg,Not match,Not Match,24
# Danielle_Spencer_0001.jpg,Dave_Tucker_0001.jpg,Not match,Not Match,28
# Danielle_Spencer_0001.jpg,Danny_Glover_0001.jpg,Not match,Not Match,24
# Danielle_Spencer_0001.jpg,Daniele_Hypolito_0001.jpg,Not match,Not Match,23
# Danielle_Spencer_0001.jpg,Demetrin_Veal_0001.jpg,Not match,Not Match,24
# Debra_Messing_0001.jpg,Daryl_Smith_0001.jpg,Not match,Not Match,30
# Debra_Messing_0001.jpg,David_Brown_0001.jpg,Not match,Not Match,28
# Debra_Messing_0001.jpg,Dean_Jacek_0001.jpg,Not match,Not Match,25
# Debra_Messing_0001.jpg,Daniele_Hypolito_0001.jpg,Not match,Not Match,27
# Debra_Messing_0001.jpg,Dave_Robertson_0001.jpg,Not match,Not Match,25
# David_Carradine_0001.jpg,Darryl_Stingley_0001.jpg,Not match,Not Match,26
# David_Carradine_0001.jpg,Daryl_Sabara_0001.jpg,Not match,Not Match,21
# David_Carradine_0001.jpg,Debra_Messing_0001.jpg,Not match,Not Match,27
# David_Carradine_0001.jpg,Daniel_Barenboim_0001.jpg,Not match,Not Match,35
# David_Carradine_0001.jpg,Darrell_Dickey_0001.jpg,Not match,Not Match,28
# Dave_Lewis_0001.jpg,Darryl_McDaniels_0001.jpg,Not match,Not Match,30
# Dave_Lewis_0001.jpg,Derrick_Taylor_0001.jpg,Not match,Not Match,31
# Dave_Lewis_0001.jpg,Debra_Shank_0001.jpg,Not match,Not Match,29
# Dave_Lewis_0001.jpg,David_McCullough_0001.jpg,Not match,Not Match,31
# Dave_Lewis_0001.jpg,David_Caraway_0001.jpg,Not match,Not Match,32
# Daryl_Smith_0001.jpg,David_Myers_0002.jpg,Not match,Not Match,28
# Daryl_Smith_0001.jpg,Derek_King_0001.jpg,Not match,Not Match,25
# Daryl_Smith_0001.jpg,Deb_Santos_0001.jpg,Not match,Not Match,23
# Daryl_Smith_0001.jpg,Darren_Clarke_0001.jpg,Not match,Not Match,34
# Daryl_Smith_0001.jpg,Daniel_Darnell_0001.jpg,Not match,Not Match,33
# Daniel_Barenboim_0001.jpg,Dennis_Hastert_0005.jpg,Not match,Not Match,29
# Daniel_Barenboim_0001.jpg,Dave_Ragone_0001.jpg,Not match,Not Match,25
# Daniel_Barenboim_0001.jpg,David_Rivkin_Jr_0001.jpg,Not match,Not Match,41
# Daniel_Barenboim_0001.jpg,David_Dodge_0001.jpg,Not match,Not Match,35
# Daniel_Barenboim_0001.jpg,Desiree_McKenzie_0001.jpg,Not match,Not Match,25
# David_Dorfman_0001.jpg,Dave_Barr_0001.jpg,Not match,Not Match,31
# David_Dorfman_0001.jpg,Daniela_Hantuchova_0001.jpg,Not match,Not Match,35
# David_Dorfman_0001.jpg,David_Dewhurst_0001.jpg,Not match,Not Match,23
# David_Dorfman_0001.jpg,Darren_Clarke_0001.jpg,Not match,Not Match,35
# David_Dorfman_0001.jpg,David_Spade_0002.jpg,Not match,Not Match,32
# Dave_McGinnis_0001.jpg,Danny_Elfman_0001.jpg,Not match,Not Match,30
# Dave_McGinnis_0001.jpg,Darrell_Issa_0001.jpg,Not match,Not Match,29
# Dave_McGinnis_0001.jpg,Denys_Arcand_0001.jpg,Not match,Not Match,25
# Dave_McGinnis_0001.jpg,Aaron_Eckhart_0001.jpg,Not match,Not Match,36
# Dave_McGinnis_0001.jpg,Daniel_Osorno_0001.jpg,Not match,Not Match,26
# Debbie_Reynolds_0004.jpg,Debra_Messing_0001.jpg,Not match,Not Match,19
# Debbie_Reynolds_0004.jpg,Daniel_Ortega_0001.jpg,Not match,Not Match,18
# Debbie_Reynolds_0004.jpg,Dennis_Kucinich_0006.jpg,Not match,Not Match,26
# Debbie_Reynolds_0004.jpg,Derrick_Rodgers_0001.jpg,Not match,Not Match,18
# Debbie_Reynolds_0004.jpg,Daniel_Barenboim_0001.jpg,Not match,Not Match,31
# Dave_Odom_0001.jpg,David_Modell_0001.jpg,Not match,Not Match,32
# Dave_Odom_0001.jpg,Dany_Heatley_0001.jpg,Not match,Not Match,34
# Dave_Odom_0001.jpg,Danis_Tanovic_0001.jpg,Not match,Not Match,24
# Dave_Odom_0001.jpg,David_Wells_0001.jpg,Not match,Not Match,21
# Dave_Odom_0001.jpg,David_Scott_Morris_0001.jpg,Not match,Not Match,28
# Dave_Ragone_0001.jpg,Daniel_Montgomery_0001.jpg,Not match,Not Match,37
# Dave_Ragone_0001.jpg,David_Millar_0001.jpg,Not match,Not Match,26
# Dave_Ragone_0001.jpg,David_Stern_0002.jpg,Not match,Not Match,30
# Dave_Ragone_0001.jpg,Daniel_Rouse_0001.jpg,Not match,Not Match,36
# Dave_Ragone_0001.jpg,David_Caruso_0003.jpg,Not match,Not Match,28
# Dennis_Archer_0001.jpg,Daniel_Montenegro_0001.jpg,Not match,Not Match,28
# Dennis_Archer_0001.jpg,Darryl_McDaniels_0001.jpg,Not match,Not Match,28
# Dennis_Archer_0001.jpg,David_Glenn_0001.jpg,Not match,Not Match,28
# Dennis_Archer_0001.jpg,Debra_Brown_0002.jpg,Not match,Not Match,18
# Dennis_Archer_0001.jpg,David_Brinkley_0001.jpg,Not match,Not Match,28
# Debra_Brown_0002.jpg,Daryl_Sabara_0001.jpg,Not match,Not Match,20
# Debra_Brown_0002.jpg,David_Nalbandian_0014.jpg,Not match,Not Match,47
# Debra_Brown_0002.jpg,Derek_Abney_0001.jpg,Not match,Not Match,20
# Debra_Brown_0002.jpg,David_Hanson_0001.jpg,Not match,Not Match,22
# Debra_Brown_0002.jpg,David_Wolf_0002.jpg,Not match,Not Match,21
# David_Heymann_0005.jpg,Debbie_Allen_0001.jpg,Not match,Not Match,33
# David_Heymann_0005.jpg,Darren_Clarke_0001.jpg,Not match,Not Match,21
# David_Heymann_0005.jpg,Dave_McNally_0001.jpg,Not match,Not Match,30
# David_Heymann_0005.jpg,Daniel_Zelman_0001.jpg,Not match,Not Match,29
# David_Heymann_0005.jpg,Dennis_Miller_0001.jpg,Not match,Not Match,29
# Aaron_Eckhart_0001.jpg,Dave_Potter_0001.jpg,Not match,Not Match,37
# Aaron_Eckhart_0001.jpg,Dave_Ragone_0001.jpg,Not match,Not Match,36
# Aaron_Eckhart_0001.jpg,David_Montoya_0001.jpg,Not match,Not Match,30
# Aaron_Eckhart_0001.jpg,David_Caruso_0003.jpg,Not match,Not Match,31
# Aaron_Eckhart_0001.jpg,Dave_Potter_0001.jpg,Not match,Not Match,37
# Danny_Green_0001.jpg,Dennis_Erickson_0002.jpg,Not match,Not Match,23
# Danny_Green_0001.jpg,Derek_Abney_0001.jpg,Not match,Not Match,34
# Danny_Green_0001.jpg,David_Provost_0001.jpg,Not match,Not Match,28
# Danny_Green_0001.jpg,Darryl_McDaniels_0001.jpg,Not match,Not Match,23
# Danny_Green_0001.jpg,Davis_Love_III_0001.jpg,Not match,Not Match,33
# David_Anderson_0001.jpg,Desiree_McKenzie_0001.jpg,Not match,Not Match,23
# David_Anderson_0001.jpg,Daryl_Smith_0001.jpg,Not match,Not Match,24
# David_Anderson_0001.jpg,David_Montoya_0001.jpg,Not match,Not Match,21
# David_Anderson_0001.jpg,David_Wolf_0002.jpg,Not match,Not Match,28
# David_Anderson_0001.jpg,Darlene_Garrettson_0001.jpg,Not match,Not Match,18
#
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x154abd8c8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x154abd8c8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x154abd8c8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x161730d90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x15b24fd08> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1 faces have been found
