# %%
# I used folders in order: 200_1, 200_2, 100, 200_3, 200_4

import import_ipynb
import light_config
import os
from light_config import *


baseDir = '/Users/denis/Downloads/lfw-deepfunneled200_1' 
# targetFile = 'Aaron_Eckhart_0001.jpg'
# target = baseDir + '/Aaron_Eckhart/' + targetFile
outputDir = '/Users/denis/Desktop'


# Iterate through all folders and all pictures in side folders

results = 'Person 1, Person 2, Expected, Result, Percent identity \n'

index = 0
targetVector = ''

for folder in os.listdir(baseDir):
    count = 0
    new = True
    for file in os.listdir(baseDir + '/' + folder):
        if new == True:
            print("new...")
            
            # Select target image, generate vector for it
            folderArr = file.split("_")
            
            folder = folderArr[0] + "_" + folderArr[1]
            
            target = baseDir + '/' + folder + '/' + file
            print("target====>", target)
            try:
                targetVector = get_embeddings([target])
                new = False
            except Exception as err:
                print("---------multiple faces detected-----------")
            

        else:
            
            if count == 5:
                new = True
            folderArr = file.split("_")
            
            folder = folderArr[0] + "_" + folderArr[1]
            path = baseDir + '/' + folder + '/' + file
            
            try:
                count += 1
                testVector = get_embeddings([path])
                result = is_match_mass(targetVector, testVector)
                textResult = 'Match'
                print("\n--------------------->", result, index)
                if result <= 50 :
                    textResult = 'Not Match'
                results = results + targetFile + ',' + file + ',' + 'Not match' +  ',' + textResult + ',' + str(result) + '\n'
            except Exception as err:
                print("---------multiple faces detected-----------")

    index = index + 1
    if index > 2:
        break
        
print('\n\n Writing output file...')
output = open(outputDir + '/results200_test.csv', 'w')
output.write(results)
output.close()
# Out:
# importing Jupyter notebook from light_config.ipynb
# new...
# target====> /Users/denis/Downloads/lfw-deepfunneled200_1/Deb_Santos/Deb_Santos_0001.jpg
# filenames =  ['/Users/denis/Downloads/lfw-deepfunneled200_1/Deb_Santos/Deb_Santos_0001.jpg']
# ...

# %% [markdown]
# ##
